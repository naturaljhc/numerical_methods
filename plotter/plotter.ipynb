# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open("../data/integration_output.json", 'r') as file:
    data = json.load(file)

# %%
x0 = data["x0"]
xend = data["xend"]
n = data["n"]

x = np.linspace(x0, xend, n + 1)
x = x[0:-1]
y = np.array(data["data"])

# %%
y
# Out:
# array([1.        , 1.        , 1.        , ..., 1.58379802, 1.58374704,
#        1.58369623])

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.title('Approximation of Antiderivative using Riemann Sums')
plt.grid(True)
plt.show()
