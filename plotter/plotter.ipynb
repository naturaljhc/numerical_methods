# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open("../data/integration_output.json", 'r') as file:
    data = json.load(file)

# %%
x0 = data["x0"]
xend = data["xend"]
n = data["n"]

x = np.linspace(x0, xend, n)
y = np.array(data["data"])

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.xlim([0, np.pi/16])
plt.ylim([0, np.sin(np.pi/16)])
plt.title('Approximation of Antiderivative using Riemann Sums')
plt.grid(True)
plt.show()

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.xlim([0, np.pi/16])
plt.ylim([0, np.sin(np.pi/16)])
plt.title('Approximation of Antiderivative using Riemann Sums')
plt.grid(True)
plt.show()
